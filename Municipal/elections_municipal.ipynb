# %%
import pandas as pd
import requests
from urllib.parse import quote
import time

# %% [markdown]
# ## import data
# from \
# https://www.oakville.ca/town-hall/elections/past-elections/2022-municipal-election/2022-municipal-election-results-by-location/'

# %%
# URL of the webpage containing the table
url = 'https://www.oakville.ca/town-hall/elections/past-elections/2022-municipal-election/2022-municipal-election-results-by-location/'

# %%
# Use pandas to read the HTML tables from the webpage
tables = pd.read_html(url)

# Display the number of tables found
print(f"Number of tables found: {len(tables)}")

# Assuming the first table is the one you're interested in
data = tables[0]

# Display the first few rows of the DataFrame
data.head()
# Out:
# Number of tables found: 18
#                                             Location  Rob Burton  Julia Hanna  \
# 0                                      0-1 Town Hall         429          402
# 1                         1-1 Walton Memorial Church         659          763
# 2                         1-2 Eastview Public School         415          507
# 3  1-3 Queen Elizabeth Park Community and Cultura...         531          541
# 4                              1-4 Hope Bible Church         404          337
#
#    Jack Kukolic
# 0            54
# 1            44
# 2            39
# 3            55
# 4            23

# %%
results_df = data.copy()

# %%
# drop total row

results_df = results_df.iloc[:-1]

# %%
# clean the location to retrieve them in geofy

results_df['Location'] = results_df['Location'].str[4:]

results_df.head()
# Out:
#                                          Location  Rob Burton  Julia Hanna  \
# 0                                            Hall         429          402
# 1                              on Memorial Church         659          763
# 2                              view Public School         415          507
# 3  n Elizabeth Park Community and Cultural Centre         531          541
# 4                                    Bible Church         404          337
#
#    Jack Kukolic
# 0            54
# 1            44
# 2            39
# 3            55
# 4            23

# %% [markdown]
# ## Retrieve and add the coordinates
#
# ### use geopify api to get the coordinates via the reverse mode

# %%
# create list of vote_places

## extract unique value of vote places
vote_places = results_df['Location'].unique()

## create a list
vote_places_list = vote_places.tolist()

print(vote_places_list[0:5])
print(f'.............................................')
print(f'number of vote places : {len(vote_places_list)}')
# Out:
# ['Town Hall', 'Walton Memorial Church', 'Eastview Public School', 'Queen Elizabeth Park Community and Cultural Centre', 'Hope Bible Church']
# .............................................
# number of vote places : 39

# %%
# API key geopify api

api_key = "8e0f597430e942f0ac38b55cf85ff32b"

# %%
# FOR LOOP can take 1m 50s for 75 places

# List to hold dictionaries for each place
places_coordinates = []  


# loop through the places in the list and retrive the ccordinates

for place in vote_places_list:

    ## complete the places to specify they are in oakville, ON

    

    full_place = f'{place}; Oakville; Ontario; Canada'
    
    try:
        encoded_place = quote(full_place)
        url = f"https://api.geoapify.com/v1/geocode/search?text={encoded_place}&apiKey={api_key}"
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()

        if data.get('features'):
            latitude = data['features'][0]['properties']['lat']
            longitude = data['features'][0]['properties']['lon']

            place_entry = {
                'Location': place,
                'full_place' : full_place,
                'lon': longitude,
                'lat': latitude
            }
            places_coordinates.append(place_entry)

        else:
            place_entry = {
                'Location': place,
                'full_place' : full_place,
                'lon': 'none',
                'lat': 'none'
            }
            places_coordinates.append(place_entry)
            print(f"No coordinates found for {place}")

        time.sleep(0.5)

    except requests.RequestException as e:
        print(f"Request failed for {place}: {e}")

print(places_coordinates)
# Out:
ontario; Canada', 'lon': -79.67374926570358, 'lat': 43.453464749999995}, {'Location': 'St. Bernadette Elementary School', 'full_place': 'St. Bernadette Elementary School; Oakville; Ontario; Canada', 'lon': -79.737916, 'lat': 43.429593}, {'Location': 'Glen Abbey Community Centre', 'full_place': 'Glen Abbey Community Centre; Oakville; Ontario; Canada', 'lon': -79.666672, 'lat': 43.447436}, {'Location': 'West Oak Public School', 'full_place': 'West Oak Public School; Oakville; Ontario; Canada', 'lon': -79.73538055559996, 'lat': 43.4486797}, {'Location': 'St. Joan of Arc Elementary School', 'full_place': 'St. Joan of Arc Elementary School; Oakville; Ontario; Canada', 'lon': -79.666672, 'lat': 43.447436}, {'Location': 'Oakville Soccer Club - Pine Glen', 'full_place': 'Oakville Soccer Club - Pine Glen; Oakville; Ontario; Canada', 'lon': -79.666672, 'lat': 43.447436}, {'Location': 'Garth Webb Secondary School', 'f ...

# %%
## create a DF with coordinates

coordinates_df = pd.DataFrame(places_coordinates)

coordinates_df.head()
# Out:
#                                             Location  \
# 0                                          Town Hall
# 1                             Walton Memorial Church
# 2                             Eastview Public School
# 3  Queen Elizabeth Park Community and Cultural Ce...
# 4                                  Hope Bible Church
#
#                                           full_place        lon        lat
# 0               Town Hall; Oakville; Ontario; Canada -79.687649  43.467344
# 1  Walton Memorial Church; Oakville; Ontario; Canada -79.713292  43.393497
# 2  Eastview Public School; Oakville; Ontario; Canada -79.709525  43.401300
# 3  Queen Elizabeth Park Community and Cultural Ce... -79.666672  43.447436
# 4       Hope Bible Church; Oakville; Ontario; Canada -79.740587  43.385129

# %%
## export coordinates (in case we don't want to run the API again)
path = "Outputs/vote_places_coordinates_municipal.csv"
coordinates_df.to_csv(path,index=False)

# %% [markdown]
# ## add coordinates to results df
# to avoid looping again , use csv file generated in path

# %%
coordinates_df = pd.read_csv(path)
coordinates_df.head()
# Out:
#                                             Location  \
# 0                                          Town Hall
# 1                             Walton Memorial Church
# 2                             Eastview Public School
# 3  Queen Elizabeth Park Community and Cultural Ce...
# 4                                  Hope Bible Church
#
#                                           full_place        lon        lat
# 0               Town Hall; Oakville; Ontario; Canada -79.687649  43.467344
# 1  Walton Memorial Church; Oakville; Ontario; Canada -79.713292  43.393497
# 2  Eastview Public School; Oakville; Ontario; Canada -79.709525  43.401300
# 3  Queen Elizabeth Park Community and Cultural Ce... -79.666672  43.447436
# 4       Hope Bible Church; Oakville; Ontario; Canada -79.740587  43.385129

# %%
## add coordinates to resulats data frame (use merge )
results_wide = pd.merge(results_df, coordinates_df, how='left', left_on= 'Location', right_on='Location')

results_wide.head()
# Out:
#                                             Location  Rob Burton  Julia Hanna  \
# 0                                          Town Hall         429          402
# 1                             Walton Memorial Church         659          763
# 2                             Eastview Public School         415          507
# 3  Queen Elizabeth Park Community and Cultural Ce...         531          541
# 4                                  Hope Bible Church         404          337
#
#    Jack Kukolic                                         full_place        lon  \
# 0            54               Town Hall; Oakville; Ontario; Canada -79.687649
# 1            44  Walton Memorial Church; Oakville; Ontario; Canada -79.713292
# 2            39  Eastview Public School; Oakville; Ontario; Canada -79.709525
# 3            55  Queen Elizabeth Park Community and Cultural Ce... -79.666672
# 4            23       Hope Bible Church; Oakville; Ontario; Canada -79.740587
#
#          lat
# 0  43.467344
# 1  43.393497
# 2  43.401300
# 3  43.447436
# 4  43.385129

# %%
### export to csv 

results_wide.to_csv("Outputs/results_municipal_wide.csv", index=False)

# %% [markdown]
# ## convert to long format for other purposes

# %%
results_wide.columns
# Out:
# Index(['Location', 'Rob Burton', 'Julia Hanna', 'Jack Kukolic', 'full_place',
#        'lon', 'lat'],
#       dtype='object')

# %%
results_long = pd.melt(results_wide, id_vars=['Location', 'full_place', 'lon', 'lat' ], var_name='candidate', value_name='votes' )
results_long
# Out:
#                                               Location  \
# 0                                            Town Hall
# 1                               Walton Memorial Church
# 2                               Eastview Public School
# 3    Queen Elizabeth Park Community and Cultural Ce...
# 4                                    Hope Bible Church
# ..                                                 ...
# 130                        Glen Abbey Community Centre
# 131                        Sixteen Mile Sports Complex
# 132                Oakville Trafalgar Community Centre
# 133                                   Sheridan College
# 134  Queen Elizabeth Park Community and Cultural Ce...
#
#                                             full_place        lon        lat  \
# 0                 Town Hall; Oakville; Ontario; Canada -79.687649  43.467344
# 1    Walton Memorial Church; Oakville; Ontario; Canada -79.713292  43.393497
# 2    Eastview Public School; Oakville; Ontario; Canada -79.709525  43.401300
# 3    Queen Elizabeth Park Community and Cultural Ce... -79.666672  43.447436
# 4         Hope Bible Church; Oakville; Ontario; Canada -79.740587  43.385129
# ..                                                 ...        ...        ...
# 130  Glen Abbey Community Centre; Oakville; Ontario... -79.666672  43.447436
# 131  Sixteen Mile Sports Complex; Oakville; Ontario... -79.749246  43.465963
# 132  Oakville Trafalgar Community Centre; Oakville;... -79.673749  43.453465
# 133        Sheridan College; Oakville; Ontario; Canada -79.699213  43.469585
# 134  Queen Elizabeth Park Community and Cultural Ce... -79.666672  43.447436
#
#         candidate  votes
# 0      Rob Burton    429
# 1      Rob Burton    659
# 2      Rob Burton    415
# 3      Rob Burton    531
# 4      Rob Burton    404
# ..            ...    ...
# 130  Jack Kukolic     34
# 131  Jack Kukolic     38
# 132  Jack Kukolic     15
# 133  Jack Kukolic      2
# 134  Jack Kukolic     16
#
# [135 rows x 6 columns]

# %%
# add rank to the result

# results_long['Rank'] = results_long.groupby(['Location', 'full_place', 'lon', 'lat']).cumcount() + 1
results_long['Rank'] = results_long.groupby(['Location', 'full_place', 'lon', 'lat'])['votes'].rank(ascending=False, method='dense')

results_long
# Out:
#                                               Location  \
# 0                                            Town Hall
# 1                               Walton Memorial Church
# 2                               Eastview Public School
# 3    Queen Elizabeth Park Community and Cultural Ce...
# 4                                    Hope Bible Church
# ..                                                 ...
# 130                        Glen Abbey Community Centre
# 131                        Sixteen Mile Sports Complex
# 132                Oakville Trafalgar Community Centre
# 133                                   Sheridan College
# 134  Queen Elizabeth Park Community and Cultural Ce...
#
#                                             full_place        lon        lat  \
# 0                 Town Hall; Oakville; Ontario; Canada -79.687649  43.467344
# 1    Walton Memorial Church; Oakville; Ontario; Canada -79.713292  43.393497
# 2    Eastview Public School; Oakville; Ontario; Canada -79.709525  43.401300
# 3    Queen Elizabeth Park Community and Cultural Ce... -79.666672  43.447436
# 4         Hope Bible Church; Oakville; Ontario; Canada -79.740587  43.385129
# ..                                                 ...        ...        ...
# 130  Glen Abbey Community Centre; Oakville; Ontario... -79.666672  43.447436
# 131  Sixteen Mile Sports Complex; Oakville; Ontario... -79.749246  43.465963
# 132  Oakville Trafalgar Community Centre; Oakville;... -79.673749  43.453465
# 133        Sheridan College; Oakville; Ontario; Canada -79.699213  43.469585
# 134  Queen Elizabeth Park Community and Cultural Ce... -79.666672  43.447436
#
#         candidate  votes  Rank
# 0      Rob Burton    429   1.0
# 1      Rob Burton    659   2.0
# 2      Rob Burton    415   2.0
# 3      Rob Burton    531   2.0
# 4      Rob Burton    404   1.0
# ..            ...    ...   ...
# 130  Jack Kukolic     34   6.0
# 131  Jack Kukolic     38   5.0
# 132  Jack Kukolic     15   6.0
# 133  Jack Kukolic      2   3.0
# 134  Jack Kukolic     16   6.0
#
# [135 rows x 7 columns]

# %%
results_long.to_csv("Outputs/results_municipal_long.csv", index=False)

# %%
# CTRL

x = results_long.sort_values(['Location', 'Rank'])
x
# Out:
#                                 Location  \
# 8            Brookdale Elementary School
# 53           Brookdale Elementary School
# 98           Brookdale Elementary School
# 17   ClearView Christian Reformed Church
# 62   ClearView Christian Reformed Church
# ..                                   ...
# 66                West Oak Public School
# 111               West Oak Public School
# 25           White Oaks Secondary School
# 70           White Oaks Secondary School
# 115          White Oaks Secondary School
#
#                                             full_place        lon        lat  \
# 8    Brookdale Elementary School; Oakville; Ontario... -79.704576  43.424315
# 53   Brookdale Elementary School; Oakville; Ontario... -79.704576  43.424315
# 98   Brookdale Elementary School; Oakville; Ontario... -79.704576  43.424315
# 17   ClearView Christian Reformed Church; Oakville;... -79.654973  43.491508
# 62   ClearView Christian Reformed Church; Oakville;... -79.654973  43.491508
# ..                                                 ...        ...        ...
# 66   West Oak Public School; Oakville; Ontario; Canada -79.735381  43.448680
# 111  West Oak Public School; Oakville; Ontario; Canada -79.735381  43.448680
# 25   White Oaks Secondary School; Oakville; Ontario... -79.702205  43.461924
# 70   White Oaks Secondary School; Oakville; Ontario... -79.702205  43.461924
# 115  White Oaks Secondary School; Oakville; Ontario... -79.702205  43.461924
#
#         candidate  votes  Rank
# 8      Rob Burton    263     1
# 53    Julia Hanna    297     2
# 98   Jack Kukolic     35     3
# 17     Rob Burton    243     1
# 62    Julia Hanna    191     2
# ..            ...    ...   ...
# 66    Julia Hanna    399     2
# 111  Jack Kukolic     31     3
# 25     Rob Burton    244     1
# 70    Julia Hanna    324     2
# 115  Jack Kukolic     44     3
#
# [135 rows x 7 columns]
